# %%
import numpy as np

# %%
menu=np.array(['cheese','bbq','veg','spicy'])
print(menu)
# Out:
# ['cheese' 'bbq' 'spicy']

# %%
prices=[100,200,150,120]
prices * 0.8
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 prices=[100,200,150,120]
# ----> 2 prices * 0.8
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
prices_np=np.array([100,200,150,120])
discounted =prices_np * 0.8
print(discounted)
# Out:
# [ 80. 160. 120.  96.]

# %%
empty_tables= np.zeros((2,3))
print("Empty Tables : \n",empty_tables)
# Out:
# Empty Tables :
#  [[0. 0. 0.]
#  [0. 0. 0.]]

# %%
full_tables= np.ones((2,3))
print("Full Tables : \n",full_tables)
# Out:
# Full Tables :
#  [[1. 1. 1.]
#  [1. 1. 1.]]

# %%
bbq_box=np.full((2,3),'BBQ')
print("Now Tables is : \n",bbq_box)
# Out:
# Now Tables is :
#  [['BBQ' 'BBQ' 'BBQ']
#  ['BBQ' 'BBQ' 'BBQ']]

# %%
bbq_box[1,1:]="VEG"
print(bbq_box)
# Out:
# [['BBQ' 'BBQ' 'BBQ']
#  ['BBQ' 'VEG' 'VEG']]

# %%
surprise_toppings=np.random.rand(2,3)
print("Random Surprise Toppings : \n",surprise_toppings)
# Out:
# Random Surprise Toppings :
#  [[0.49175221 0.9609099  0.25275797]
#  [0.58128261 0.97498558 0.90287473]]

# %%
kids_order=np.random.randint(1,8,(3,2))
print("Kids Slice orders : \n",kids_order)
# Out:
# Kids Slice orders :
#  [[3 7]
#  [3 6]
#  [1 1]]

# %%
singnature_pizzas=np.identity(3)
print("Signature Pizzas Tables : \n",singnature_pizzas)
# Out:
# Signature Pizzas Tables :
#  [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]

# %%
singnature_pizzas=np.identity(3)
singnature_pizzas=singnature_pizzas.astype(int)
print("Signature Pizzas Tables : \n",singnature_pizzas)
print(type(singnature_pizzas))
# Out:
# Signature Pizzas Tables :
#  [[1 0 0]
#  [0 1 0]
#  [0 0 1]]
# <class 'numpy.ndarray'>

# %%
delivary_times=np.arange(0,120,15)
print(delivary_times)
# Out:
# [  0  15  30  45  60  75  90 105]

# %%
cooking_shifts=np.linspace(0,60,6)
print(cooking_shifts)
# Out:
# [ 0. 12. 24. 36. 48. 60.]

# %%
orders=np.array(['cheese','veg','spicy','bbq'])
print(orders[1:3])
# Out:
# ['veg' 'spicy']

# %%
orders=np.array([
    ['cheese','veg'],
    ['spicy','bbq ']
])
print(orders[0,1])
# Out:
# veg

# %%
print(orders[1,:])
# Out:
# ['spicy' 'bbq ']

# %%
print(orders[:,0])
# Out:
# ['cheese' 'spicy']

# %%
sales=np.array([1200,1500,900,2000])
print("Max sales : ",np.max(sales))
# Out:
# Max sales :  2000

# %%
print("Best Seller : ",np.argmax(sales))
# Out:
# Best Seller :  3

# %%
print("Worst Seller : ",np.argmin(sales))
# Out:
# Worst Seller :  2
