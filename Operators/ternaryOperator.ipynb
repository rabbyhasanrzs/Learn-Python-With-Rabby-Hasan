# %% [markdown]
# ## The Ternary Operator
# The ternary operator allows you to assign one value if a condition is true, and another if it is false:

# %%
if (age:=20) < 18: # using walrus operator here:
    print("Minor");
else:
    print("Adult");
# Out:
# Adult

# %%
print("Adult" if (name:=20)>18 else "Minor");
# Out:
# Adult
